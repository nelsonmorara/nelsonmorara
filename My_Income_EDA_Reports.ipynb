# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Income Dataset.csv')
df
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country income
# 0       39         State-gov   77516  ...             40   United-States  <=50K
# 1       50  Self-emp-not-inc   83311  ...             13   United-States  <=50K
# 2       38           Private  215646  ...             40   United-States  <=50K
# 3       53           Private  234721  ...             40   United-States  <=50K
# 4       28           Private  338409  ...             40            Cuba  <=50K
# ...    ...               ...     ...  ...            ...             ...    ...
# 32556   27           Private  257302  ...             38   United-States  <=50K
# 32557   40           Private  154374  ...             40   United-States   >50K
# 32558   58           Private  151910  ...             40   United-States  <=50K
# 32559   22           Private  201490  ...             20   United-States  <=50K
# 32560   52      Self-emp-inc  287927  ...             40   United-States   >50K
#
# ...

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt  ... hours-per-week  native-country income
# 0   39         State-gov   77516  ...             40   United-States  <=50K
# 1   50  Self-emp-not-inc   83311  ...             13   United-States  <=50K
# 2   38           Private  215646  ...             40   United-States  <=50K
# 3   53           Private  234721  ...             40   United-States  <=50K
# 4   28           Private  338409  ...             40            Cuba  <=50K
# 5   37           Private  284582  ...             40   United-States  <=50K
# 6   49           Private  160187  ...             16         Jamaica  <=50K
# 7   52  Self-emp-not-inc  209642  ...             45   United-States   >50K
# 8   31           Private   45781  ...             50   United-States   >50K
# 9   42           Private  159449  ...             40   United-States   >50K
#
# [10 rows x 15 columns]

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt  ... hours-per-week  native-country income
# 32556   27       Private  257302  ...             38   United-States  <=50K
# 32557   40       Private  154374  ...             40   United-States   >50K
# 32558   58       Private  151910  ...             40   United-States  <=50K
# 32559   22       Private  201490  ...             20   United-States  <=50K
# 32560   52  Self-emp-inc  287927  ...             40   United-States   >50K
#
# [5 rows x 15 columns]

# %%
df.describe()
# Out:
#                 age        fnlwgt  ...  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  ...  32561.000000    32561.000000
# mean      38.581647  1.897784e+05  ...     87.303830       40.437456
# std       13.640433  1.055500e+05  ...    402.960219       12.347429
# min       17.000000  1.228500e+04  ...      0.000000        1.000000
# 25%       28.000000  1.178270e+05  ...      0.000000       40.000000
# 50%       37.000000  1.783560e+05  ...      0.000000       40.000000
# 75%       48.000000  2.370510e+05  ...      0.000000       45.000000
# max       90.000000  1.484705e+06  ...   4356.000000       99.000000
#
# [8 rows x 6 columns]

# %%
# !pip install pandas-profiling --upgrade
# Out:
# ...
#      |████████████████████████████████| 245kB 5.7MB/s
# ...
#      |████████████████████████████████| 3.2MB 6.7MB/s
# ...
#      |████████████████████████████████| 61kB 6.0MB/s
# ...
#      |████████████████████████████████| 81kB 7.2MB/s
# ...
#      |████████████████████████████████| 1.1MB 28.6MB/s
# ...
#      |████████████████████████████████| 296kB 37.6MB/s
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-cp37-none-any.whl size=27085 sha256=da252b84ec0ace419ba485c3e04daec4a1432d4f328747bf19f1a21c3bf6112b
#   Stored in directory: /root/.cache/pip/wheels/43/07/ac/7c5a9d708d65247ac1f94066cf1db075540b85716c30255459
# ...
#   Created wheel for phik: filename=phik-0.11.2-cp37-none-any.whl size=1107413 sha256=63c3f9e976947b193f7088a89648bad4de0e56aeaf0b7d6acce062d4eb804f41
#   Stored in directory: /root/.cache/pip/wheels/c0/a3/b0/f27b1cfe32ea131a3715169132ff6d85653789e80e966c3bf6
# Successfully built htmlmin phik
# ...

# %%
from pandas_profiling import ProfileReport

# %%
df_eda_report  = ProfileReport(df, minimal=True)

# %%
df_eda_report.to_file("Income EDA Report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install sweetviz --upgrade
# Out:
# Requirement already up-to-date: sweetviz in /usr/local/lib/python3.7/dist-packages (2.1.0)
# ...

# %%
import sweetviz as sv

# %%
my_report = sv.analyze(df)
my_report.show_html("Income Sweetviz EDA Report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report Income Sweetviz EDA Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# !pip install autoviz --upgrade
# Out:
# Requirement already up-to-date: autoviz in /usr/local/lib/python3.7/dist-packages (0.0.81)
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %%
AV = AutoViz_Class()

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
AV.AutoViz(filename="", dfte = df, verbose = 2)
# Out:
# Shape of your Data Set: (32561, 15)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
# Data Set Shape: 32561 rows, 15 cols
# Data Set columns info:
# * age: 0 nulls, 73 unique vals, most common: {36: 898, 31: 888}
# * workclass: 1836 nulls, 8 unique vals, most common: {'Private': 22696, 'Self-emp-not-inc': 2541}
# * fnlwgt: 0 nulls, 21648 unique vals, most common: {164190: 13, 203488: 13}
# * education: 0 nulls, 16 unique vals, most common: {'HS-grad': 10501, 'Some-college': 7291}
# * education-num: 0 nulls, 16 unique vals, most common: {9: 10501, 10: 7291}
# * marital-status: 0 nulls, 7 unique vals, most common: {'Married-civ-spouse': 14976, 'Never-married': 10683}
# * occupation: 1843 nulls, 14 unique vals, most common: {'Prof-specialty': 4140, 'Craft-repair': 4099}
# * relationship: 0 nulls, 6 unique vals, most common: {'Husband': 13193, 'Not-in-family': 8305}
# ...

# %%
AV.AutoViz(filename="", dfte = df, verbose = 2)
# Out:
# Shape of your Data Set: (32561, 15)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
# Data Set Shape: 32561 rows, 15 cols
# Data Set columns info:
# * age: 0 nulls, 73 unique vals, most common: {36: 898, 31: 888}
# * workclass: 1836 nulls, 8 unique vals, most common: {'Private': 22696, 'Self-emp-not-inc': 2541}
# * fnlwgt: 0 nulls, 21648 unique vals, most common: {164190: 13, 203488: 13}
# * education: 0 nulls, 16 unique vals, most common: {'HS-grad': 10501, 'Some-college': 7291}
# * education-num: 0 nulls, 16 unique vals, most common: {9: 10501, 10: 7291}
# * marital-status: 0 nulls, 7 unique vals, most common: {'Married-civ-spouse': 14976, 'Never-married': 10683}
# * occupation: 1843 nulls, 14 unique vals, most common: {'Prof-specialty': 4140, 'Craft-repair': 4099}
# * relationship: 0 nulls, 6 unique vals, most common: {'Husband': 13193, 'Not-in-family': 8305}
# ...
